# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import tensorflow as tf
import keras
import cv2
import numpy as np # linear algebra
import pandas as pd

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
# from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers , models, optimizers

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *

# %%
img_shape = 48
batch_size = 64
train_data_path = '../input/fer2013/train/'
test_data_path = '../input/fer2013/test/'

# %%
train_gen = ImageDataGenerator(
        rescale= 1 / 255,
        # Data Augmentation
        rotation_range=10,
        zoom_range= 0.2,
        width_shift_range= 0.1,
        height_shift_range= 0.1,
        fill_mode ="nearest"
    
    )

test_gen = ImageDataGenerator(rescale= 1 / 255 )

# %%
train_data = train_gen.flow_from_directory(
    train_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size,
    subset='training', 
)


test_data = test_gen.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size,
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
def Create_CNN_Model():
    
    model = Sequential()
    
    #CNN1
    model.add(Conv2D(32, (3,3), activation='relu', input_shape=(img_shape, img_shape, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(64,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN2
    model.add(Conv2D(64, (3,3), activation='relu', ))
    model.add(BatchNormalization())
    model.add(Conv2D(128,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN3
    model.add(Conv2D(128, (3,3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    
    
    model.add(Flatten())
    
    #ANN
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(7,activation='softmax'))
    
    
    return model

# %%
CNN_Model = Create_CNN_Model()

CNN_Model.summary()

CNN_Model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# 2022-11-10 06:21:37.472498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:37.473491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:37.776262: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:37.777167: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:37.777972: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:37.778837: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:37.780793: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-10 06:21:38.035573: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:38.036390: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:38.037116: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:38.037843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:38.038696: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:38.039483: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:42.647981: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:42.648899: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:42.649632: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:42.650347: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:42.651063: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:42.651766: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-10 06:21:42.657396: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-10 06:21:42.658176: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 46, 46, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 21, 21, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 21, 21, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 128)         147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 9, 9, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 256)         295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              6554624
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 7,837,895
# Trainable params: 7,832,519
# Non-trainable params: 5,376
# _________________________________________________________________

# %%
plot_model(CNN_Model)

# %%
steps_per_epoch = train_data.n // train_data.batch_size
validation_steps = test_data.n // test_data.batch_size

# %%
CNN_history = CNN_Model.fit( train_data , 
                            validation_data= test_data ,
                            epochs=50, batch_size= batch_size,
                            
                             steps_per_epoch= steps_per_epoch, 
                            validation_steps=validation_steps
                           )
# Out:
# 2022-11-09 09:54:03.787573: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-11-09 09:54:07.613054: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 448/448 [==============================] - 175s 365ms/step - loss: 2.0603 - accuracy: 0.1983 - val_loss: 1.8356 - val_accuracy: 0.2483
# Epoch 2/50
# 448/448 [==============================] - 63s 140ms/step - loss: 1.7893 - accuracy: 0.2682 - val_loss: 1.7707 - val_accuracy: 0.3048
# Epoch 3/50
# 448/448 [==============================] - 62s 139ms/step - loss: 1.6426 - accuracy: 0.3536 - val_loss: 1.5860 - val_accuracy: 0.3746
# Epoch 4/50
# 169/448 [==========>...................] - ETA: 36s - loss: 1.5417 - accuracy: 0.4016Epoch 6/50
# 448/448 [==============================] - 62s 139ms/step - loss: 1.3626 - accuracy: 0.4787 - val_loss: 1.4284 - val_accuracy: 0.4651
# Epoch 7/50
# 448/448 [==============================] - 62s 137ms/step - loss: 1.3186 - accuracy: 0.4990 - val_loss: 1.2415 - val_accuracy: 0.5239
# Epoch 8/50
# 448/448 [==============================] - 62s 138ms/step - loss: 1.2820 - accuracy: 0.5164 - val_loss: 1.1844 - val_accuracy: 0.5416
# Epoch 9/50
# 448/448 [==============================] - 62s 139ms/step - loss: 1.2562 - accuracy: 0.5299 - val_loss: 1.1397 - val_accuracy: 0.5661
# Epoch 10/50
# 448/448 [==============================] - 61s 136ms/step - loss: 1.2238 - accuracy: 0.5404 - val_loss: 1.2928 - val_accuracy: 0.5163
# Epoch 11/50
# 448/448 [==============================] - 62s 138ms/step - loss: 1.1981 - accuracy: 0.5547 - val_loss: 1.1434 - val_accuracy: 0.5709
# Epoch 12/50
# 448/448 [==============================] - 61s 137ms/step - loss: 1.1748 - accuracy: 0.5651 - val_loss: 1.1217 - val_accuracy: 0.5806
# Epoch 13/50
# 448/448 [==============================] - 61s 136ms/step - loss: 1.1595 - accuracy: 0.5742 - val_loss: 1.1223 - val_accuracy: 0.5759
# Epoch 14/50
# 448/448 [==============================] - 61s 137ms/step - loss: 1.1428 - accuracy: 0.5740 - val_loss: 1.0580 - val_accuracy: 0.6021
# Epoch 15/50
# 448/448 [==============================] - 62s 139ms/step - loss: 1.1246 - accuracy: 0.5877 - val_loss: 1.1246 - val_accuracy: 0.5773
# Epoch 16/50
# 448/448 [==============================] - 62s 138ms/step - loss: 1.1109 - accuracy: 0.5901 - val_loss: 1.1225 - val_accuracy: 0.5819
# Epoch 17/50
# 448/448 [==============================] - 62s 137ms/step - loss: 1.0824 - accuracy: 0.6028 - val_loss: 1.0207 - val_accuracy: 0.6191
# Epoch 18/50
# 448/448 [==============================] - 61s 137ms/step - loss: 1.0808 - accuracy: 0.6057 - val_loss: 1.1663 - val_accuracy: 0.5650
# Epoch 19/50
# 448/448 [==============================] - 62s 139ms/step - loss: 1.0647 - accuracy: 0.6081 - val_loss: 1.0187 - val_accuracy: 0.6290
# Epoch 20/50
# 448/448 [==============================] - 62s 137ms/step - loss: 1.0555 - accuracy: 0.6138 - val_loss: 1.0202 - val_accuracy: 0.6223
# Epoch 21/50
# 448/448 [==============================] - 61s 137ms/step - loss: 1.0452 - accuracy: 0.6171 - val_loss: 0.9914 - val_accuracy: 0.6328
# Epoch 22/50
# 448/448 [==============================] - 62s 139ms/step - loss: 1.0292 - accuracy: 0.6219 - val_loss: 0.9994 - val_accuracy: 0.6226
# Epoch 23/50
# 448/448 [==============================] - 62s 138ms/step - loss: 1.0176 - accuracy: 0.6294 - val_loss: 1.0235 - val_accuracy: 0.6219
# Epoch 24/50
# 448/448 [==============================] - 65s 145ms/step - loss: 1.0135 - accuracy: 0.6288 - val_loss: 0.9909 - val_accuracy: 0.6288
# Epoch 25/50
# 448/448 [==============================] - 63s 140ms/step - loss: 0.9962 - accuracy: 0.6334 - val_loss: 1.1033 - val_accuracy: 0.5922
# Epoch 26/50
# 448/448 [==============================] - 62s 138ms/step - loss: 0.9861 - accuracy: 0.6418 - val_loss: 0.9966 - val_accuracy: 0.6279
# Epoch 27/50
# 448/448 [==============================] - 62s 138ms/step - loss: 0.9718 - accuracy: 0.6470 - val_loss: 0.9792 - val_accuracy: 0.6426
# Epoch 28/50
# 448/448 [==============================] - 68s 152ms/step - loss: 0.9659 - accuracy: 0.6461 - val_loss: 0.9886 - val_accuracy: 0.6369
# Epoch 29/50
# 448/448 [==============================] - 62s 138ms/step - loss: 0.9603 - accuracy: 0.6481 - val_loss: 0.9759 - val_accuracy: 0.6413
# Epoch 31/50
# 448/448 [==============================] - 61s 136ms/step - loss: 0.9393 - accuracy: 0.6561 - val_loss: 0.9673 - val_accuracy: 0.6392
# Epoch 32/50
# 448/448 [==============================] - 62s 138ms/step - loss: 0.9344 - accuracy: 0.6604 - val_loss: 0.9578 - val_accuracy: 0.6496
# Epoch 33/50
# 448/448 [==============================] - 62s 138ms/step - loss: 0.9245 - accuracy: 0.6658 - val_loss: 0.9471 - val_accuracy: 0.6536
# Epoch 34/50
# 448/448 [==============================] - 61s 136ms/step - loss: 0.9179 - accuracy: 0.6660 - val_loss: 0.9542 - val_accuracy: 0.6536
# Epoch 35/50
# 448/448 [==============================] - 62s 139ms/step - loss: 0.9107 - accuracy: 0.6706 - val_loss: 0.9530 - val_accuracy: 0.6494
# Epoch 36/50
# 448/448 [==============================] - 61s 136ms/step - loss: 0.8967 - accuracy: 0.6747 - val_loss: 0.9398 - val_accuracy: 0.6579
# Epoch 37/50
# 448/448 [==============================] - 63s 140ms/step - loss: 0.9039 - accuracy: 0.6737 - val_loss: 0.9759 - val_accuracy: 0.6507
# Epoch 38/50
# 448/448 [==============================] - 63s 140ms/step - loss: 0.8972 - accuracy: 0.6768 - val_loss: 0.9488 - val_accuracy: 0.6547
# Epoch 39/50
# 448/448 [==============================] - 62s 138ms/step - loss: 0.8805 - accuracy: 0.6826 - val_loss: 0.9556 - val_accuracy: 0.6514
# Epoch 40/50
# 448/448 [==============================] - 63s 141ms/step - loss: 0.8814 - accuracy: 0.6810 - val_loss: 0.9344 - val_accuracy: 0.6576
# Epoch 41/50
# 448/448 [==============================] - 61s 137ms/step - loss: 0.8656 - accuracy: 0.6870 - val_loss: 0.9625 - val_accuracy: 0.6494
# Epoch 42/50
# 448/448 [==============================] - 62s 139ms/step - loss: 0.8559 - accuracy: 0.6922 - val_loss: 0.9442 - val_accuracy: 0.6542
# Epoch 43/50
# 448/448 [==============================] - 64s 143ms/step - loss: 0.8627 - accuracy: 0.6892 - val_loss: 0.9360 - val_accuracy: 0.6593
# Epoch 44/50
# 448/448 [==============================] - 62s 139ms/step - loss: 0.8474 - accuracy: 0.6947 - val_loss: 1.0226 - val_accuracy: 0.6408
# Epoch 45/50
# 448/448 [==============================] - 62s 139ms/step - loss: 0.8416 - accuracy: 0.6974 - val_loss: 0.9493 - val_accuracy: 0.6571
# Epoch 46/50
# 448/448 [==============================] - 62s 137ms/step - loss: 0.8377 - accuracy: 0.7004 - val_loss: 0.9565 - val_accuracy: 0.6613
# Epoch 47/50
# 448/448 [==============================] - 60s 134ms/step - loss: 0.8281 - accuracy: 0.7031 - val_loss: 0.9284 - val_accuracy: 0.6621
# Epoch 48/50
# 448/448 [==============================] - 62s 138ms/step - loss: 0.8257 - accuracy: 0.7038 - val_loss: 0.9279 - val_accuracy: 0.6716
# Epoch 49/50
# 448/448 [==============================] - 61s 137ms/step - loss: 0.8148 - accuracy: 0.7053 - val_loss: 0.9820 - val_accuracy: 0.6507
# Epoch 50/50
# 448/448 [==============================] - 61s 137ms/step - loss: 0.8173 - accuracy: 0.7080 - val_loss: 0.9258 - val_accuracy: 0.6749

# %%
CNN_Model.save("kaggle_model.h5")

# %%
CNN_Score = CNN_Model.evaluate(test_data)

print("    Test Loss: {:.5f}".format(CNN_Score[0]))
print("Test Accuracy: {:.2f}%".format(CNN_Score[1] * 100))
# Out:
# 113/113 [==============================] - 7s 65ms/step - loss: 0.9249 - accuracy: 0.6753
#     Test Loss: 0.92489
# Test Accuracy: 67.53%

# %%
def plot_curves(history):

    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    accuracy = history.history["accuracy"]
    val_accuracy = history.history["val_accuracy"]

    epochs = range(len(history.history["loss"]))

    plt.figure(figsize=(15,5))

    #plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label = "training_loss")
    plt.plot(epochs, val_loss, label = "val_loss")
    plt.title("Loss")
    plt.xlabel("epochs")
    plt.legend()

    #plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label = "training_accuracy")
    plt.plot(epochs, val_accuracy, label = "val_accuracy")
    plt.title("Accuracy")
    plt.xlabel("epochs")
    plt.legend()

# %%
import matplotlib.pyplot as plt
plot_curves(CNN_history)

# %%
CNN_Predictions = CNN_Model.predict(test_data)

# Choosing highest probalbilty class in every prediction 
CNN_Predictions = np.argmax(CNN_Predictions, axis=1)

# %%
test_data.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix, classification_report

fig, ax= plt.subplots(figsize=(15,10))

cm=confusion_matrix(test_data.labels, CNN_Predictions)

sns.heatmap(cm, annot=True, fmt='g', ax=ax)

ax.set_xlabel('Predicted labels',fontsize=15, fontweight='bold')
ax.set_ylabel('True labels', fontsize=15, fontweight='bold')
ax.set_title('CNN Confusion Matrix', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'CNN Confusion Matrix')

# %%
# Classification Report

report = classification_report(test_data.classes, CNN_Predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.58      0.61       958
#            1       0.79      0.53      0.63       111
#            2       0.57      0.41      0.48      1024
#            3       0.87      0.86      0.86      1774
#            4       0.59      0.71      0.64      1233
#            5       0.55      0.57      0.56      1247
#            6       0.74      0.83      0.78       831
#
#     accuracy                           0.68      7178
#    macro avg       0.68      0.64      0.65      7178
# weighted avg       0.68      0.68      0.67      7178
